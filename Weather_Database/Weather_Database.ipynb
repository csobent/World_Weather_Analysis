# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime

# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# Create list for lats and lngs
coordinates = list(lats_lngs)

# %%
# Perform an API call with the OpenWeatherMap
# Starting URL for API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Get nearest city using citipy module.
# Import citipy module 
from citipy import citipy

# Create cities list
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then it will be added to list.
    if city not in cities:
        cities.append(city)
        
print(cities)
# Out:
# ['port alfred', 'lebu', 'alofi', 'miraflores', 'albany', 'manokwari', 'severo-kurilsk', 'joao pinheiro', 'athabasca', 'yellowknife', 'bambous virieux', 'busselton', 'ribeira grande', 'arraial do cabo', 'vestmannaeyjar', 'lanigan', 'port blair', 'east london', 'bluff', 'vaitupu', 'tuktoyaktuk', 'chingirlau', 'rosetown', 'hobart', 'elat', 'comodoro rivadavia', 'gambela', 'sendafa', 'te anau', 'attawapiskat', 'muzhi', 'hamilton', 'tuatapere', 'chuy', 'solvychegodsk', 'salalah', 'nenjiang', 'edgewater', 'pevek', 'iqaluit', 'bantou', 'inuvik', 'norman wells', 'cabo san lucas', 'nanakuli', 'longyearbyen', 'leshukonskoye', 'vaini', 'odweyne', 'rikitea', 'ilulissat', 'barrow', 'hithadhoo', 'husavik', 'hambantota', 'issoire', 'kapaa', 'atuona', 'namibe', 'constitucion', 'avarua', 'berlevag', 'barentsburg', 'awang', 'taolanaro', 'bethel', 'punta arenas', 'mataura', 'nikolskoye', 'petropavlovsk-kamchatskiy', 'hermanus', 'panlaitan', 'saldanha', 'sao filipe', 'ponta do sol', 'lagoa', 'ayer itam', 'taltal', 'pacific grove', 'new norfolk', 'chemal', 'umzimvubu', 'juneau', 'colwyn bay', 'la ronge', 'jardim', 'bandarbeyla', 'aykhal', 'louisbourg', 'yulara', 'coquimbo', 'kouango', 'klaksvik', 'shestakovo', 'hilo', 'grand gaube', 'thompson', 'zanjan', 'jamestown', 'esperance', 'qaanaaq', 'ushuaia', 'yaan', 'hofn', 'magomeni', 'asau', 'nome', 'kieta', 'gaoua', 'pereslavl-zalesskiy', 'bakchar', 'zhangye', 'lata', 'nizwa', 'brae', 'kushmurun', 'arman', 'udupi', 'mitsamiouli', 'port elizabeth', 'mar del plata', 'nata', 'fairbanks', 'crib point', 'calvinia', 'evensk', 'cagli', 'robertsport', 'port lincoln', 'christchurch', 'pisco', 'matamoros', 'yenagoa', 'komsomolskiy', 'oktyabrskoye', 'geraldton', 'codrington', 'batemans bay', 'ahipara', 'lazaro cardenas', 'tibati', 'tsagan aman', 'mega', 'moranbah', 'dikson', 'chokurdakh', 'khatanga', 'kahului', 'aden', 'san cristobal', 'bredasdorp', 'santa vitoria do palmar', 'dedovichi', 'bilma', 'provideniya', 'cayenne', 'kaitangata', 'spornoye', 'cape town', 'eregli', 'dandong', 'roma', 'ngunguru', 'otuzco', 'lompoc', 'bargal', 'eufaula', 'kirakira', 'peniche', 'butaritari', 'kawhia', 'malwan', 'port macquarie', 'grevena', 'karonga', 'carnarvon', 'mzimba', 'paarl', 'georgetown', 'fortuna', 'mayabon', 'sirsa', 'owando', 'santa marta', 'saint george', 'mys shmidta', 'mangan', 'warqla', 'half moon bay', 'talcahuano', 'sabang', 'namatanai', 'tayoltita', 'kadykchan', 'kodiak', 'vagur', 'taungdwingyi', 'yerbogachen', 'grand river south east', 'basco', 'omsukchan', 'ajdabiya', 'marsh harbour', 'sioux lookout', 'zitacuaro', 'barra', 'roros', 'makakilo city', 'caravelas', 'bosobolo', 'sept-iles', 'bacolod', 'agde', 'tadine', 'constantine', 'dali', 'donskoy', 'toora-khem', 'halifax', 'souillac', 'nizhneyansk', 'chardara', 'port keats', 'uniao da victoria', 'soyo', 'karaul', 'lorengau', 'talaya', 'shubarshi', 'clyde river', 'san ramon', 'sobolevo', 'bikaner', 'broome', 'piacabucu', 'asnaes', 'soluno-dmitriyevskoye', 'palpa', 'ebolowa', 'fort nelson', 'kavieng', 'beaverlodge', 'sao jose da coroa grande', 'tarko-sale', 'belushya guba', 'galesong', 'castro', 'ankang', 'cidreira', 'kuressaare', 'amderma', 'saskylakh', 'bangassou', 'kharitonovo', 'celestun', 'seoul', 'verkhnevilyuysk', 'mehamn', 'katsuura', 'cherskiy', 'gouyave', 'illoqqortoormiut', 'tawkar', 'alyangula', 'merauke', 'bengkulu', 'severo-yeniseyskiy', 'jaguariaiva', 'diego de almagro', 'asosa', 'luderitz', 'oistins', 'batsfjord', 'halalo', 'korfez', 'saint-pierre', 'sinnamary', 'wajima', 'keti bandar', 'puerto del rosario', 'college', 'sorland', 'westport', 'mackay', 'hasaki', 'puerto ayora', 'san patricio', 'forbes', 'lufilufi', 'fevralsk', 'pedernales', 'el balyana', 'cape girardeau', 'saint-philippe', 'eldoret', 'tuscaloosa', 'chapais', 'deputatskiy', 'port hawkesbury', 'palabuhanratu', 'narsaq', 'forio', 'zhob', 'nelson bay', 'aleksandrov gay', 'bataipora', 'nishihara', 'flin flon', 'sakakah', 'qaqortoq', 'tiksi', 'scarborough', 'qasigiannguit', 'havre-sai ...

# %%
# Empty list to hold weather data
city_data = []

# Create beginning of list for organization purposes.
print("Beginning Data Retrieval  ")
print("--------------------------")

# Counters
record_count = 1
set_count = 1

# Loop through all cities
for i, city in enumerate(cities):
    # Group cities in sets of 50 for easier viewing.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(10)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
          
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Retrieve latitude, longitude, max temp, % humidity, % cloudiness, wind speed, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["main"]

        # Append city information into city_data list.
        city_data.append({"City": city.title(),
                 "Lat": city_lat,
                 "Lng": city_lng,
                 "Max Temp": city_max_temp,
                 "Humidity": city_humidity,
                 "Cloudiness": city_clouds,
                 "Wind Speed": city_wind,
                 "Country": city_country,
                 "Current Description": city_descript})

# If an error occurs, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Finished retrieving data.
print("--------------------------")

print("Data Retrieval Completed  ")
print("--------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | alofi
# Processing Record 4 of Set 1 | miraflores
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | manokwari
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | joao pinheiro
# Processing Record 9 of Set 1 | athabasca
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | vestmannaeyjar
# Processing Record 16 of Set 1 | lanigan
# Processing Record 17 of Set 1 | port blair
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | chingirlau
# Processing Record 23 of Set 1 | rosetown
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | elat
# Processing Record 26 of Set 1 | comodoro rivadavia
# Processing Record 27 of Set 1 | gambela
# Processing Record 28 of Set 1 | sendafa
# Processing Record 29 of Set 1 | te anau
# Processing Record 30 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 1 | muzhi
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | tuatapere
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | solvychegodsk
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | nenjiang
# Processing Record 38 of Set 1 | edgewater
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | bantou
# Processing Record 42 of Set 1 | inuvik
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | nanakuli
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | leshukonskoye
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | odweyne
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | ilulissat
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | husavik
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | issoire
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | namibe
# Processing Record 10 of Set 2 | constitucion
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | berlevag
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | awang
# Processing Record 15 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 2 | hermanus
# Processing Record 22 of Set 2 | panlaitan
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | sao filipe
# Processing Record 25 of Set 2 | ponta do sol
# Processing Record 26 of Set 2 | lagoa
# Processing Record 27 of Set 2 | ayer itam
# City not found. Skipping...
# Processing Record 28 of Set 2 | taltal
# Processing Record 29 of Set 2 | pacific grove
# Processing Record 30 of Set 2 | new norfolk
# Processing Record 31 of Set 2 | chemal
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | juneau
# Processing Record 34 of Set 2 | colwyn bay
# Processing Record 35 of Set 2 | la ronge
# Processing Record 36 of Set 2 | jardim
# Processing Record 37 of Set 2 | bandarbeyla
# Processing Record 38 of Set 2 | aykhal
# Processing Record 39 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 2 | yulara
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | kouango
# Processing Record 43 of Set 2 | klaksvik
# Processing Record 44 of Set 2 | shestakovo
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | grand gaube
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | zanjan
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | qaanaaq
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | yaan
# Processing Record 4 of Set 3 | hofn
# Processing Record 5 of Set 3 | magomeni
# Processing Record 6 of Set 3 | asau
# Processing Record 7 of Set 3 | nome
# Processing Record 8 of Set 3 | kieta
# Processing Record 9 of Set 3 | gaoua
# Processing Record 10 of Set 3 | pereslavl-zalesskiy
# Processing Record 11 of Set 3 | bakchar
# Processing Record 12 of Set 3 | zhangye
# Processing Record 13 of Set 3 | lata
# Processing Record 14 of Set 3 | nizwa
# Processing Record 15 of Set 3 | brae
# Processing Record 16 of Set 3 | kushmurun
# Processing Record 17 of Set 3 | arman
# Processing Record 18 of Set 3 | udupi
# Processing Record 19 of Set 3 | mitsamiouli
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | mar del plata
# Processing Record 22 of Set 3 | nata
# Processing Record 23 of Set 3 | fairbanks
# Processing Record 24 of Set 3 | crib point
# Processing Record 25 of Set 3 | calvinia
# Processing Record 26 of Set 3 | evensk
# Processing Record 27 of Set 3 | cagli
# Processing Record 28 of Set 3 | robertsport
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | christchurch
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | matamoros
# Processing Record 33 of Set 3 | yenagoa
# Processing Record 34 of Set 3 | komsomolskiy
# Processing Record 35 of Set 3 | oktyabrskoye
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | codrington
# Processing Record 38 of Set 3 | batemans bay
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | lazaro cardenas
# Processing Record 41 of Set 3 | tibati
# Processing Record 42 of Set 3 | tsagan aman
# Processing Record 43 of Set 3 | mega
# Processing Record 44 of Set 3 | moranbah
# Processing Record 45 of Set 3 | dikson
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | kahului
# Processing Record 49 of Set 3 | aden
# Processing Record 50 of Set 3 | san cristobal
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | santa vitoria do palmar
# Processing Record 3 of Set 4 | dedovichi
# Processing Record 4 of Set 4 | bilma
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | cayenne
# Processing Record 7 of Set 4 | kaitangata
# Processing Record 8 of Set 4 | spornoye
# Processing Record 9 of Set 4 | cape town
# Processing Record 10 of Set 4 | eregli
# Processing Record 11 of Set 4 | dandong
# Processing Record 12 of Set 4 | roma
# Processing Record 13 of Set 4 | ngunguru
# Processing Record 14 of Set 4 | otuzco
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 4 | eufaula
# Processing Record 18 of Set 4 | kirakira
# Processing Record 19 of Set 4 | peniche
# Processing Record 20 of Set 4 | butaritari
# Processing Record 21 of Set 4 | kawhia
# Processing Record 22 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 4 | port macquarie
# Processing Record 24 of Set 4 | grevena
# Processing Record 25 of Set 4 | karonga
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | mzimba
# Processing Record 28 of Set 4 | paarl
# Processing Record 29 of Set 4 | georgetown
# Processing Record 30 of Set 4 | fortuna
# Processing Record 31 of Set 4 | mayabon
# Processing Record 32 of Set 4 | sirsa
# Processing Record 33 of Set 4 | owando
# Processing Record 34 of Set 4 | santa marta
# Processing Record 35 of Set 4 | saint george
# Processing Record 36 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 4 | mangan
# Processing Record 38 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 4 | half moon bay
# Processing Record 40 of Set 4 | talcahuano
# Processing Record 41 of Set 4 | sabang
# Processing Record 42 of Set 4 | namatanai
# Processing Record 43 of Set 4 | tayoltita
# Processing Record 44 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | vagur
# Processing Record 47 of Set 4 | taungdwingyi
# Processing Record 48 of Set 4 | yerbogachen
# Processing Record 49 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 4 | basco
# Processing Record 1 of Set 5 | omsukchan
# Processing Record 2 of Set 5 | ajdabiya
# Processing Record 3 of Set 5 | marsh harbour
# Processing Record 4 of Set 5 | sioux lookout
# Processing Record 5 of Set 5 | zitacuaro
# Processing Record 6 of Set 5 | barra
# Processing Record 7 of Set 5 | roros
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | caravelas
# Processing Record 10 of Set 5 | bosobolo
# Processing Record 11 of Set 5 | sept-iles
# Processing Record 12 of Set 5 | bacolod
# Processing Record 13 of Set 5 | agde
# Processing Record 14 of Set 5 | tadine
# Processing Record 15 of Set 5 | constantine
# Processing Record 16 of Set 5 | dali
# Processing Record 17 of Set 5 | donskoy
# Processing Record 18 of Set 5 | toora-khem
# Processing Record 19 of Set 5 | halifax
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | chardara
# Processing Record 23 of Set 5 | port keats
# Processing Record 24 of Set 5 | uniao da victoria
# City not found. Skipping...
# Processing Record 25 of Set 5 | soyo
# Processing Record 26 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 5 | lorengau
# Processing Record 28 of Set 5 | talaya
# Processing Record 29 of Set 5 | shubarshi
# Processing Record 30 of Set 5 | clyde river
# Processing Record 31 of Set 5 | san ramon
# Processing Record 32 of Set 5 | sobolevo
# Processing Record 33 of Set 5 | bikaner
# Processing Record 34 of Set 5 | broome
# Processing Record 35 of Set 5 | piacabucu
# Processing Record 36 of Set 5 | asnaes
# Processing Record 37 of Set 5 | soluno-dmitriyevskoye
# Processing Record 38 of Set 5 | palpa
# Processing Record 39 of Set 5 | ebolowa
# Processing Record 40 of Set 5 | fort nelson
# Processing Record 41 of Set 5 | kavieng
# Processing Record 42 of Set 5 | beaverlodge
# Processing Record 43 of Set 5 | sao jose da coroa grande
# Processing Record 44 of Set 5 | tarko-sale
# Processing Record 45 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 5 | galesong
# Processing Record 47 of Set 5 | castro
# Processing Record 48 of Set 5 | ankang
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | kuressaare
# Processing Record 1 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 6 | saskylakh
# Processing Record 3 of Set 6 | bangassou
# Processing Record 4 of Set 6 | kharitonovo
# Processing Record 5 of Set 6 | celestun
# Processing Record 6 of Set 6 | seoul
# Processing Record 7 of Set 6 | verkhnevilyuysk
# Processing Record 8 of Set 6 | mehamn
# Processing Record 9 of Set 6 | katsuura
# Processing Record 10 of Set 6 | cherskiy
# Processing Record 11 of Set 6 | gouyave
# Processing Record 12 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 14 of Set 6 | alyangula
# Processing Record 15 of Set 6 | merauke
# Processing Record 16 of Set 6 | bengkulu
# Processing Record 17 of Set 6 | severo-yeniseyskiy
# Processing Record 18 of Set 6 | jaguariaiva
# Processing Record 19 of Set 6 | diego de almagro
# Processing Record 20 of Set 6 | asosa
# Processing Record 21 of Set 6 | luderitz
# Processing Record 22 of Set 6 | oistins
# Processing Record 23 of Set 6 | batsfjord
# Processing Record 24 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 6 | korfez
# Processing Record 26 of Set 6 | saint-pierre
# Processing Record 27 of Set 6 | sinnamary
# Processing Record 28 of Set 6 | wajima
# Processing Record 29 of Set 6 | keti bandar
# Processing Record 30 of Set 6 | puerto del rosario
# Processing Record 31 of Set 6 | college
# Processing Record 32 of Set 6 | sorland
# Processing Record 33 of Set 6 | westport
# Processing Record 34 of Set 6 | mackay
# Processing Record 35 of Set 6 | hasaki
# Processing Record 36 of Set 6 | puerto ayora
# Processing Record 37 of Set 6 | san patricio
# Processing Record 38 of Set 6 | forbes
# Processing Record 39 of Set 6 | lufilufi
# Processing Record 40 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 41 of Set 6 | pedernales
# Processing Record 42 of Set 6 | el balyana
# City not found. Skipping...
# Processing Record 43 of Set 6 | cape girardeau
# Processing Record 44 of Set 6 | saint-philippe
# Processing Record 45 of Set 6 | eldoret
# Processing Record 46 of Set 6 | tuscaloosa
# Processing Record 47 of Set 6 | chapais
# Processing Record 48 of Set 6 | deputatskiy
# Processing Record 49 of Set 6 | port hawkesbury
# Processing Record 50 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 1 of Set 7 | narsaq
# Processing Record 2 of Set 7 | forio
# Processing Record 3 of Set 7 | zhob
# Processing Record 4 of Set 7 | nelson bay
# Processing Record 5 of Set 7 | aleksandrov gay
# Processing Record 6 of Set 7 | bataipora
# Processing Record 7 of Set 7 | nishihara
# Processing Record 8 of Set 7 | flin flon
# Processing Record 9 of Set 7 | sakakah
# Processing Record 10 of Set 7 | qaqortoq
# Processing Record 11 of Set 7 | tiksi
# Processing Record 12 of Set 7 | scarborough
# Processing Record 13 of Set 7 | qasigiannguit
# Processing Record 14 of Set 7 | havre-saint-pierre
# Processing Record 15 of Set 7 | alibag
# Processing Record 16 of Set 7 | northam
# Processing Record 17 of Set 7 | gremyachye
# City not found. Skipping...
# Processing Record 18 of Set 7 | jizan
# Processing Record 19 of Set 7 | spasskoye
# Processing Record 20 of Set 7 | galveston
# Processing Record 21 of Set 7 | guantanamo
# Processing Record 22 of Set 7 | hays
# Processing Record 23 of Set 7 | riverton
# Processing Record 24 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 25 of Set 7 | tateyama
# Processing Record 26 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 7 | hvide sande
# Processing Record 28 of Set 7 | okha
# Processing Record 29 of Set 7 | tura
# Processing Record 30 of Set 7 | cacule
# Processing Record 31 of Set 7 | victoria
# Processing Record 32 of Set 7 | port-gentil
# Processing Record 33 of Set 7 | portland
# Processing Record 34 of Set 7 | sovetskiy
# Processing Record 35 of Set 7 | betioky
# Processing Record 36 of Set 7 | america dourada
# Processing Record 37 of Set 7 | matinhos
# Processing Record 38 of Set 7 | nanortalik
# Processing Record 39 of Set 7 | huarmey
# Processing Record 40 of Set 7 | trinidad
# Processing Record 41 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 7 | yar-sale
# Processing Record 43 of Set 7 | airai
# Processing Record 44 of Set 7 | hobyo
# Processing Record 45 of Set 7 | houston
# Processing Record 46 of Set 7 | svetlogorsk
# Processing Record 47 of Set 7 | ikorodu
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | bar harbor
# Processing Record 50 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 8 | garowe
# Processing Record 2 of Set 8 | kermanshah
# Processing Record 3 of Set 8 | torbay
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | creel
# Processing Record 6 of Set 8 | purpe
# Processing Record 7 of Set 8 | cockburn town
# Processing Record 8 of Set 8 | nouna
# Processing Record 9 of Set 8 | saint-gaudens
# Processing Record 10 of Set 8 | upernavik
# Processing Record 11 of Set 8 | zurrieq
# Processing Record 12 of Set 8 | agua buena
# Processing Record 13 of Set 8 | shelburne
# Processing Record 14 of Set 8 | george
# Processing Record 15 of Set 8 | kuytun
# Processing Record 16 of Set 8 | lethem
# Processing Record 17 of Set 8 | varkkallai
# Processing Record 18 of Set 8 | luwuk
# Processing Record 19 of Set 8 | rawson
# Processing Record 20 of Set 8 | honningsvag
# Processing Record 21 of Set 8 | san pedro
# Processing Record 22 of Set 8 | thinadhoo
# Processing Record 23 of Set 8 | horsham
# Processing Record 24 of Set 8 | parlakimidi
# Processing Record 25 of Set 8 | atar
# Processing Record 26 of Set 8 | laguna
# Processing Record 27 of Set 8 | gashua
# Processing Record 28 of Set 8 | iskateley
# Processing Record 29 of Set 8 | ancud
# Processing Record 30 of Set 8 | zhigansk
# Processing Record 31 of Set 8 | tabriz
# Processing Record 32 of Set 8 | burnie
# Processing Record 33 of Set 8 | tual
# Processing Record 34 of Set 8 | along
# Processing Record 35 of Set 8 | san jose
# Processing Record 36 of Set 8 | pozo colorado
# Processing Record 37 of Set 8 | aspindza
# Processing Record 38 of Set 8 | high rock
# Processing Record 39 of Set 8 | talnakh
# Processing Record 40 of Set 8 | dzaoudzi
# Processing Record 41 of Set 8 | matagami
# Processing Record 42 of Set 8 | chaohu
# Processing Record 43 of Set 8 | starotimoshkino
# Processing Record 44 of Set 8 | mount isa
# Processing Record 45 of Set 8 | coahuayana
# Processing Record 46 of Set 8 | viedma
# Processing Record 47 of Set 8 | nhulunbuy
# Processing Record 48 of Set 8 | pemangkat
# Processing Record 49 of Set 8 | ishinomaki
# Processing Record 50 of Set 8 | dubbo
# Processing Record 1 of Set 9 | kavaratti
# Processing Record 2 of Set 9 | ostrovnoy
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 9 | abis
# Processing Record 6 of Set 9 | coihaique
# Processing Record 7 of Set 9 | fort-shevchenko
# Processing Record 8 of Set 9 | lima
# Processing Record 9 of Set 9 | mareeba
# Processing Record 10 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 11 of Set 9 | worland
# Processing Record 12 of Set 9 | porto santo
# Processing Record 13 of Set 9 | hervey bay
# Processing Record 14 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | lavrentiya
# Processing Record 16 of Set 9 | samarai
# Processing Record 17 of Set 9 | mazamari
# Processing Record 18 of Set 9 | hargeysa
# Processing Record 19 of Set 9 | sfantu gheorghe
# Processing Record 20 of Set 9 | bonavista
# Processing Record 21 of Set 9 | saint-ambroise
# Processing Record 22 of Set 9 | khasan
# Processing Record 23 of Set 9 | fortuna foothills
# Processing Record 24 of Set 9 | pangnirtung
# Processing Record 25 of Set 9 | tombouctou
# Processing Record 26 of Set 9 | alto araguaia
# Processing Record 27 of Set 9 | kruisfontein
# Processing Record 28 of Set 9 | capreol
# Processing Record 29 of Set 9 | margate
# Processing Record 30 of Set 9 | monrovia
# Processing Record 31 of Set 9 | mocuba
# Processing Record 32 of Set 9 | eirunepe
# Processing Record 33 of Set 9 | nieuw amsterdam
# Processing Record 34 of Set 9 | denpasar
# Processing Record 35 of Set 9 | santa cruz
# Processing Record 36 of Set 9 | harlingen
# Processing Record 37 of Set 9 | jiuquan
# Processing Record 38 of Set 9 | pirovskoye
# Processing Record 39 of Set 9 | winneba
# Processing Record 40 of Set 9 | waddan
# Processing Record 41 of Set 9 | ushtobe
# Processing Record 42 of Set 9 | tabas
# Processing Record 43 of Set 9 | sokolo
# Processing Record 44 of Set 9 | avera
# Processing Record 45 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 9 | oksfjord
# Processing Record 47 of Set 9 | xadani
# City not found. Skipping...
# Processing Record 48 of Set 9 | savannah bight
# Processing Record 49 of Set 9 | lalmohan
# Processing Record 50 of Set 9 | sungai pelek

# %%
# Convert the array of dictionaries to a Pandas Dataframe.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df= city_data_df[new_column_order]
city_data_df.head(10)

# %%
# Create output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export city_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City ID")
