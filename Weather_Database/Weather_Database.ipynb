# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime

# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# Create list for lats and lngs
coordinates = list(lats_lngs)

# %%
# Perform an API call with the OpenWeatherMap
# Starting URL for API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Get nearest city using citipy module.
# Import citipy module 
from citipy import citipy

# Create cities list
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then it will be added to list.
    if city not in cities:
        cities.append(city)
        
print(cities)
# Out:
# ['pirsagi', 'houma', 'severo-kurilsk', 'attawapiskat', 'coihaique', 'port alfred', 'yellowknife', 'bengkulu', 'geraldton', 'neiafu', 'karratha', 'ushuaia', 'punta arenas', 'alta floresta', 'norman wells', 'atuona', 'fortuna', 'innisfail', 'chokurdakh', 'kapaa', 'nome', 'tshikapa', 'erdenet', 'sao filipe', 'indianola', 'miramar', 'quatre cocos', 'taolanaro', 'arraial do cabo', 'sao jose da coroa grande', 'qaanaaq', 'castro', 'tsihombe', 'saint-philippe', 'avarua', 'umzimvubu', 'matay', 'aswan', 'sembe', 'upernavik', 'solano', 'illoqqortoormiut', 'wiwili', 'noyabrsk', 'itoman', 'dong hoi', 'utrecht', 'jamestown', 'souillac', 'rikitea', 'faanui', 'carnarvon', 'alta', 'emerald', 'bredasdorp', 'healdsburg', 'hithadhoo', 'bandar-e lengeh', 'kovdor', 'muros', 'guisa', 'kushmurun', 'butaritari', 'georgetown', 'lishu', 'kahului', 'ozernovskiy', 'cape town', 'santarem', 'svetlyy', 'zhigansk', 'kuusamo', 'mataura', 'amuntai', 'palmer', 'clyde river', 'lebu', 'afonso claudio', 'leningradskiy', 'barentu', 'new norfolk', 'port shepstone', 'hobart', 'hinche', 'demba', 'kijang', 'posse', 'barrow', 'barentsburg', 'marsh harbour', 'ribeira grande', 'busselton', 'riyadh', 'klaksvik', 'albany', 'salinopolis', 'cabo san lucas', 'kodiak', 'preston', 'torbay', 'mago', 'karaul', 'nalut', 'bathsheba', 'micheweni', 'tuktoyaktuk', 'broome', 'strezhevoy', 'tasiilaq', 'matadi', 'derbent', 'gat', 'grindavik', 'touros', 'changji', 'lagoa', 'lasa', 'svetlogorsk', 'tsalka', 'mount gambier', 'clinton', 'lagos', 'teguise', 'petropavlovsk-kamchatskiy', 'mys shmidta', 'makakilo city', 'miyazu', 'la ronge', 'ketchikan', 'airai', 'nemuro', 'fort nelson', 'port elizabeth', 'antofagasta', 'chuy', 'great bend', 'vacaria', 'isangel', 'ossora', 'progreso', 'beringovskiy', 'hami', 'peniche', 'la asuncion', 'grand river south east', 'husavik', 'nobres', 'vaini', 'saint-augustin', 'lac du bonnet', 'hermanus', 'dipkarpaz', 'nikolskoye', 'saint george', 'thompson', 'vila velha', 'belushya guba', 'westport', 'ternate', 'dzaoudzi', 'bargal', 'east london', 'umm lajj', 'cherskiy', 'san patricio', 'sinnamary', 'igrim', 'bluff', 'kavieng', 'edd', 'puerto ayora', 'el sauzal', 'aklavik', 'pangnirtung', 'lensk', 'ust-kuyga', 'yenagoa', 'syracuse', 'rudnogorsk', 'bethel', 'alyangula', 'saint-pierre', 'pisco', 'heinola', 'talnakh', 'tiksi', 'acapulco', 'jibuti', 'matto', 'russell', 'kavaratti', 'san cristobal', 'taltal', 'jihlava', 'sentyabrskiy', 'coalinga', 'lososina', 'tura', 'wagar', 'port hardy', 'havelock', 'sayyan', 'fort saint john', 'sobolevo', 'palmares do sul', 'portland', 'yulara', 'rodeo', 'puerto madero', 'nuevo progreso', 'hilo', 'alice springs', 'nuuk', 'turukhansk', 'santa vitoria do palmar', 'puerto escondido', 'richards bay', 'iskateley', 'iqaluit', 'manono', 'teliucu inferior', 'nelson bay', 'sorong', 'esperance', 'milton', 'bambous virieux', 'bismarck', 'jardim', 'lorengau', 'ilulissat', 'xining', 'tyulgan', 'zuwarah', 'longyearbyen', 'sumbawanga', 'ahipara', 'bridlington', 'uvinza', 'tebingtinggi', 'necochea', 'kirakira', 'mweka', 'santa maria', 'san rafael', 'cooma', 'saint anthony', 'chadan', 'padang', 'yaan', 'merauke', 'khatanga', 'araouane', 'jiayuguan', 'beyneu', 'chirilagua', 'coahuayana', 'nanortalik', 'shahr-e babak', 'hofn', 'port macquarie', 'aleksandrov gay', 'victoria', 'santa rosa', 'belmonte', 'bubaque', 'semnan', 'pacific grove', 'zhanaozen', 'inhambane', 'lavrentiya', 'ust-maya', 'vanimo', 'bazaliya', 'baykit', 'arlit', 'santa isabel do rio negro', 'oranjestad', 'acarau', 'ponta do sol', 'alugan', 'matara', 'flinders', 'bahia honda', 'tashara', 'ancud', 'lobanovo', 'belem de sao francisco', 'payson', 'kachikau', 'katsuura', 'samarai', 'labuhan', 'karimganj', 'the valley', 'samusu', 'mar del plata', 'tautira', 'srandakan', 'west plains', 'mahebourg', 'tidore', 'tessalit', 'sao felix do xingu', 'salalah', 'wolverhampton', 'marquette', 'katakwi', 'krasnyy yar', 'salinas', 'puerto ayacucho', 'burica', 'opunake', 'port-cartier', 'adre', 'skalistyy', ' ...

# %%
# Empty list to hold weather data
city_data = []

# Create beginning of list for organization purposes.
print("Beginning Data Retrieval  ")
print("--------------------------")

# Counters
record_count = 1
set_count = 1

# Loop through all cities
for i, city in enumerate(cities):
    # Group cities in sets of 50 for easier viewing.
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
        time.sleep(10)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
          
    # Add 1 to the record count.
    record_count += 1
    

city_weather = requests.get(city_url).json()

city_lat = city_weather["coord"]["lat"]
cit_lng = city_weather["coord"]["lon"]
city_max_temp = city_weather["main"]["temp_max"]
city_humidity = city_weather["main"]["humidity"]
city_clouds = city_weather["clouds"]["all"]
city_wind = city_weather["wind"]["speed"]
city_country = city_weather["sys"]["country"]
city_descript = city_weather["weather"][0]["main"]

# Finished retrieving data.
print("--------------------------")

print("Data Retrieval Completed  ")
print("--------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 of Set 1 | pirsagi
# Processing Record 2 of Set 1 | houma
# Processing Record 3 of Set 1 | severo-kurilsk
# Processing Record 4 of Set 1 | attawapiskat
# Processing Record 5 of Set 1 | coihaique
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | geraldton
# Processing Record 10 of Set 1 | neiafu
# Processing Record 11 of Set 1 | karratha
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | alta floresta
# Processing Record 15 of Set 1 | norman wells
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | innisfail
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | nome
# Processing Record 22 of Set 1 | tshikapa
# Processing Record 23 of Set 1 | erdenet
# Processing Record 24 of Set 1 | sao filipe
# Processing Record 25 of Set 1 | indianola
# Processing Record 26 of Set 1 | miramar
# Processing Record 27 of Set 1 | quatre cocos
# Processing Record 28 of Set 1 | taolanaro
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | sao jose da coroa grande
# Processing Record 31 of Set 1 | qaanaaq
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | tsihombe
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | umzimvubu
# Processing Record 37 of Set 1 | matay
# Processing Record 38 of Set 1 | aswan
# Processing Record 39 of Set 1 | sembe
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | solano
# Processing Record 42 of Set 1 | illoqqortoormiut
# Processing Record 43 of Set 1 | wiwili
# Processing Record 44 of Set 1 | noyabrsk
# Processing Record 45 of Set 1 | itoman
# Processing Record 46 of Set 1 | dong hoi
# Processing Record 47 of Set 1 | utrecht
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | faanui
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | alta
# Processing Record 4 of Set 2 | emerald
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | healdsburg
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | bandar-e lengeh
# Processing Record 9 of Set 2 | kovdor
# Processing Record 10 of Set 2 | muros
# Processing Record 11 of Set 2 | guisa
# Processing Record 12 of Set 2 | kushmurun
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | lishu
# Processing Record 16 of Set 2 | kahului
# Processing Record 17 of Set 2 | ozernovskiy
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | santarem
# Processing Record 20 of Set 2 | svetlyy
# Processing Record 21 of Set 2 | zhigansk
# Processing Record 22 of Set 2 | kuusamo
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | amuntai
# Processing Record 25 of Set 2 | palmer
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | afonso claudio
# Processing Record 29 of Set 2 | leningradskiy
# Processing Record 30 of Set 2 | barentu
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | port shepstone
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | hinche
# Processing Record 35 of Set 2 | demba
# Processing Record 36 of Set 2 | kijang
# Processing Record 37 of Set 2 | posse
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | barentsburg
# Processing Record 40 of Set 2 | marsh harbour
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | busselton
# Processing Record 43 of Set 2 | riyadh
# Processing Record 44 of Set 2 | klaksvik
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | salinopolis
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | preston
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | mago
# Processing Record 2 of Set 3 | karaul
# Processing Record 3 of Set 3 | nalut
# Processing Record 4 of Set 3 | bathsheba
# Processing Record 5 of Set 3 | micheweni
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | broome
# Processing Record 8 of Set 3 | strezhevoy
# Processing Record 9 of Set 3 | tasiilaq
# Processing Record 10 of Set 3 | matadi
# Processing Record 11 of Set 3 | derbent
# Processing Record 12 of Set 3 | gat
# Processing Record 13 of Set 3 | grindavik
# Processing Record 14 of Set 3 | touros
# Processing Record 15 of Set 3 | changji
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | lasa
# Processing Record 18 of Set 3 | svetlogorsk
# Processing Record 19 of Set 3 | tsalka
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | clinton
# Processing Record 22 of Set 3 | lagos
# Processing Record 23 of Set 3 | teguise
# Processing Record 24 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 3 | mys shmidta
# Processing Record 26 of Set 3 | makakilo city
# Processing Record 27 of Set 3 | miyazu
# Processing Record 28 of Set 3 | la ronge
# Processing Record 29 of Set 3 | ketchikan
# Processing Record 30 of Set 3 | airai
# Processing Record 31 of Set 3 | nemuro
# Processing Record 32 of Set 3 | fort nelson
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | antofagasta
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | great bend
# Processing Record 37 of Set 3 | vacaria
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | ossora
# Processing Record 40 of Set 3 | progreso
# Processing Record 41 of Set 3 | beringovskiy
# Processing Record 42 of Set 3 | hami
# Processing Record 43 of Set 3 | peniche
# Processing Record 44 of Set 3 | la asuncion
# Processing Record 45 of Set 3 | grand river south east
# Processing Record 46 of Set 3 | husavik
# Processing Record 47 of Set 3 | nobres
# Processing Record 48 of Set 3 | vaini
# Processing Record 49 of Set 3 | saint-augustin
# Processing Record 50 of Set 3 | lac du bonnet
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | dipkarpaz
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | saint george
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | vila velha
# Processing Record 7 of Set 4 | belushya guba
# Processing Record 8 of Set 4 | westport
# Processing Record 9 of Set 4 | ternate
# Processing Record 10 of Set 4 | dzaoudzi
# Processing Record 11 of Set 4 | bargal
# Processing Record 12 of Set 4 | east london
# Processing Record 13 of Set 4 | umm lajj
# Processing Record 14 of Set 4 | cherskiy
# Processing Record 15 of Set 4 | san patricio
# Processing Record 16 of Set 4 | sinnamary
# Processing Record 17 of Set 4 | igrim
# Processing Record 18 of Set 4 | bluff
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | edd
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | el sauzal
# Processing Record 23 of Set 4 | aklavik
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | lensk
# Processing Record 26 of Set 4 | ust-kuyga
# Processing Record 27 of Set 4 | yenagoa
# Processing Record 28 of Set 4 | syracuse
# Processing Record 29 of Set 4 | rudnogorsk
# Processing Record 30 of Set 4 | bethel
# Processing Record 31 of Set 4 | alyangula
# Processing Record 32 of Set 4 | saint-pierre
# Processing Record 33 of Set 4 | pisco
# Processing Record 34 of Set 4 | heinola
# Processing Record 35 of Set 4 | talnakh
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | acapulco
# Processing Record 38 of Set 4 | jibuti
# Processing Record 39 of Set 4 | matto
# Processing Record 40 of Set 4 | russell
# Processing Record 41 of Set 4 | kavaratti
# Processing Record 42 of Set 4 | san cristobal
# Processing Record 43 of Set 4 | taltal
# Processing Record 44 of Set 4 | jihlava
# Processing Record 45 of Set 4 | sentyabrskiy
# Processing Record 46 of Set 4 | coalinga
# Processing Record 47 of Set 4 | lososina
# Processing Record 48 of Set 4 | tura
# Processing Record 49 of Set 4 | wagar
# Processing Record 50 of Set 4 | port hardy

# %%
# Convert the array of dictionaries to a Pandas Dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
