# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from datetime import datetime

# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval   ")
print("---------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Date": city_date})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | nuevo progreso
# Processing Record 3 of Set 1 | tiksi
# Processing Record 4 of Set 1 | avarua
# Processing Record 5 of Set 1 | waddan
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | churapcha
# Processing Record 12 of Set 1 | khasan
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | porto novo
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | korla
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | ilulissat
# Processing Record 19 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 1 | new norfolk
# Processing Record 21 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 1 | pandan
# Processing Record 23 of Set 1 | southbridge
# Processing Record 24 of Set 1 | torbay
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | omis
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | morondava
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | vestmanna
# Processing Record 34 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | palmerston
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | faya
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | port lincoln
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | coffs harbour
# Processing Record 47 of Set 1 | asau
# Processing Record 48 of Set 1 | tvoroyri
# Processing Record 49 of Set 1 | geri
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | meulaboh
# Processing Record 3 of Set 2 | meadow lake
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | berlevag
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | provideniya
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | kesennuma
# City not found. Skipping...
# Processing Record 10 of Set 2 | dunedin
# Processing Record 11 of Set 2 | necochea
# Processing Record 12 of Set 2 | vila velha
# Processing Record 13 of Set 2 | collie
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | chicama
# Processing Record 16 of Set 2 | aksehir
# Processing Record 17 of Set 2 | havoysund
# Processing Record 18 of Set 2 | khorramshahr
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | kaitangata
# Processing Record 22 of Set 2 | kargala
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | zhigansk
# Processing Record 25 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 26 of Set 2 | ponta do sol
# Processing Record 27 of Set 2 | saint-pierre
# Processing Record 28 of Set 2 | wilmington
# Processing Record 29 of Set 2 | hohhot
# Processing Record 30 of Set 2 | cherepovets
# Processing Record 31 of Set 2 | jacareacanga
# Processing Record 32 of Set 2 | belaya gora
# Processing Record 33 of Set 2 | karratha
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | los llanos de aridane
# Processing Record 37 of Set 2 | casimcea
# Processing Record 38 of Set 2 | jalu
# Processing Record 39 of Set 2 | wuwei
# Processing Record 40 of Set 2 | okhotsk
# Processing Record 41 of Set 2 | migori
# Processing Record 42 of Set 2 | wanxian
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | thinadhoo
# Processing Record 45 of Set 2 | carutapera
# Processing Record 46 of Set 2 | lasa
# Processing Record 47 of Set 2 | berezovyy
# Processing Record 48 of Set 2 | cooma
# Processing Record 49 of Set 2 | warrnambool
# Processing Record 50 of Set 2 | moron
# Processing Record 1 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 3 | hermiston
# Processing Record 3 of Set 3 | mombetsu
# Processing Record 4 of Set 3 | richards bay
# Processing Record 5 of Set 3 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | smithers
# Processing Record 9 of Set 3 | yuksekova
# Processing Record 10 of Set 3 | crib point
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | prince rupert
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 3 | takhtamygda
# Processing Record 16 of Set 3 | marienburg
# Processing Record 17 of Set 3 | coquimbo
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | ondjiva
# Processing Record 20 of Set 3 | san vicente
# Processing Record 21 of Set 3 | labuhan
# Processing Record 22 of Set 3 | mahebourg
# Processing Record 23 of Set 3 | muros
# Processing Record 24 of Set 3 | sao joao da barra
# Processing Record 25 of Set 3 | maloy
# Processing Record 26 of Set 3 | aragarcas
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | iqaluit
# Processing Record 29 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 3 | constitucion
# Processing Record 31 of Set 3 | kodiak
# Processing Record 32 of Set 3 | yar-sale
# Processing Record 33 of Set 3 | bilma
# Processing Record 34 of Set 3 | qaanaaq
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | asyut
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | katobu
# Processing Record 39 of Set 3 | lorengau
# Processing Record 40 of Set 3 | zapolyarnyy
# Processing Record 41 of Set 3 | darhan
# Processing Record 42 of Set 3 | valleyview
# Processing Record 43 of Set 3 | riyadh
# Processing Record 44 of Set 3 | bontang
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | sucre
# Processing Record 47 of Set 3 | port-gentil
# Processing Record 48 of Set 3 | saint-leu
# Processing Record 49 of Set 3 | abu dhabi
# Processing Record 50 of Set 3 | inhambane
# Processing Record 1 of Set 4 | khategaon
# Processing Record 2 of Set 4 | coruripe
# Processing Record 3 of Set 4 | uyemskiy
# Processing Record 4 of Set 4 | olden
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | marystown
# Processing Record 7 of Set 4 | castro
# Processing Record 8 of Set 4 | starokostyantyniv
# Processing Record 9 of Set 4 | manggar
# Processing Record 10 of Set 4 | clyde river
# Processing Record 11 of Set 4 | bouar
# Processing Record 12 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 4 | luderitz
# Processing Record 14 of Set 4 | payakumbuh
# Processing Record 15 of Set 4 | manadhoo
# Processing Record 16 of Set 4 | carnarvon
# Processing Record 17 of Set 4 | chingirlau
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | katsuura
# Processing Record 21 of Set 4 | port elizabeth
# Processing Record 22 of Set 4 | mareeba
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | shelopugino
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | chillicothe
# Processing Record 28 of Set 4 | sistranda
# Processing Record 29 of Set 4 | baghdad
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | bengkulu
# Processing Record 32 of Set 4 | sakakah
# Processing Record 33 of Set 4 | bathsheba
# Processing Record 34 of Set 4 | formosa
# Processing Record 35 of Set 4 | yellowknife
# Processing Record 36 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 37 of Set 4 | huarmey
# Processing Record 38 of Set 4 | arlit
# Processing Record 39 of Set 4 | ostrow mazowiecka
# Processing Record 40 of Set 4 | bogande
# Processing Record 41 of Set 4 | palkonda
# Processing Record 42 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 4 | asosa
# Processing Record 44 of Set 4 | camacha
# Processing Record 45 of Set 4 | opuwo
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | mount gambier
# Processing Record 48 of Set 4 | shakawe
# Processing Record 49 of Set 4 | idrinskoye
# Processing Record 50 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 5 | bitam
# Processing Record 2 of Set 5 | mecca
# Processing Record 3 of Set 5 | san juan
# Processing Record 4 of Set 5 | codrington
# Processing Record 5 of Set 5 | nekhayevskiy
# Processing Record 6 of Set 5 | sterling
# Processing Record 7 of Set 5 | flagstaff
# Processing Record 8 of Set 5 | salinopolis
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | huilong
# Processing Record 11 of Set 5 | wagar
# Processing Record 12 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 13 of Set 5 | henties bay
# Processing Record 14 of Set 5 | piopio
# Processing Record 15 of Set 5 | kalmunai
# Processing Record 16 of Set 5 | mazagao
# Processing Record 17 of Set 5 | genhe
# Processing Record 18 of Set 5 | vila franca do campo
# Processing Record 19 of Set 5 | fairbanks
# Processing Record 20 of Set 5 | svetlyy
# Processing Record 21 of Set 5 | cabo san lucas
# Processing Record 22 of Set 5 | upernavik
# Processing Record 23 of Set 5 | samarai
# Processing Record 24 of Set 5 | nanortalik
# Processing Record 25 of Set 5 | bada
# Processing Record 26 of Set 5 | georgetown
# Processing Record 27 of Set 5 | maceio
# Processing Record 28 of Set 5 | sorong
# Processing Record 29 of Set 5 | phnum penh
# City not found. Skipping...
# Processing Record 30 of Set 5 | fukuma
# Processing Record 31 of Set 5 | fez
# Processing Record 32 of Set 5 | lebu
# Processing Record 33 of Set 5 | carora
# Processing Record 34 of Set 5 | sao filipe
# Processing Record 35 of Set 5 | tyazhinskiy
# Processing Record 36 of Set 5 | gobabis
# Processing Record 37 of Set 5 | malkangiri
# Processing Record 38 of Set 5 | mandali
# Processing Record 39 of Set 5 | puerto madryn
# Processing Record 40 of Set 5 | port blair
# Processing Record 41 of Set 5 | metro
# Processing Record 42 of Set 5 | lahaina
# Processing Record 43 of Set 5 | nicoya
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | taltal
# Processing Record 46 of Set 5 | beyneu
# Processing Record 47 of Set 5 | mutis
# Processing Record 48 of Set 5 | katherine
# Processing Record 49 of Set 5 | puro
# Processing Record 50 of Set 5 | hasaki
# Processing Record 1 of Set 6 | kavaratti
# Processing Record 2 of Set 6 | coahuayana
# Processing Record 3 of Set 6 | kushima
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | les cayes
# Processing Record 6 of Set 6 | ous
# Processing Record 7 of Set 6 | ayia galini
# Processing Record 8 of Set 6 | uchiza
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | general pico
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | kanye
# Processing Record 13 of Set 6 | picayune
# Processing Record 14 of Set 6 | linhares
# Processing Record 15 of Set 6 | puerto escondido
# Processing Record 16 of Set 6 | caravelas
# Processing Record 17 of Set 6 | north bend
# Processing Record 18 of Set 6 | rapid city
# Processing Record 19 of Set 6 | erdenet
# Processing Record 20 of Set 6 | lerwick
# Processing Record 21 of Set 6 | mackay
# Processing Record 22 of Set 6 | isiro
# Processing Record 23 of Set 6 | sabang
# Processing Record 24 of Set 6 | baherden
# Processing Record 25 of Set 6 | raposa
# Processing Record 26 of Set 6 | sangar
# Processing Record 27 of Set 6 | brainerd
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | mar del plata
# Processing Record 30 of Set 6 | regidor
# Processing Record 31 of Set 6 | pemangkat
# Processing Record 32 of Set 6 | nipawin
# Processing Record 33 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 6 | lata
# Processing Record 35 of Set 6 | zeya
# Processing Record 36 of Set 6 | bitung
# Processing Record 37 of Set 6 | hambantota
# Processing Record 38 of Set 6 | lac du bonnet
# Processing Record 39 of Set 6 | slupsk
# Processing Record 40 of Set 6 | beloha
# Processing Record 41 of Set 6 | wanning
# Processing Record 42 of Set 6 | tsaratanana
# Processing Record 43 of Set 6 | kahului
# Processing Record 44 of Set 6 | muisne
# Processing Record 45 of Set 6 | fort collins
# Processing Record 46 of Set 6 | karasjok
# Processing Record 47 of Set 6 | tokat
# Processing Record 48 of Set 6 | quinta do anjo
# Processing Record 49 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 6 | grand gaube
# Processing Record 1 of Set 7 | mirabad
# Processing Record 2 of Set 7 | hemsedal
# Processing Record 3 of Set 7 | atbasar
# Processing Record 4 of Set 7 | buin
# Processing Record 5 of Set 7 | payson
# Processing Record 6 of Set 7 | mandalgovi
# Processing Record 7 of Set 7 | plettenberg bay
# Processing Record 8 of Set 7 | hawalli
# Processing Record 9 of Set 7 | pratapgarh
# Processing Record 10 of Set 7 | dudinka
# Processing Record 11 of Set 7 | olafsvik
# Processing Record 12 of Set 7 | najran
# Processing Record 13 of Set 7 | mayna
# Processing Record 14 of Set 7 | kathu
# Processing Record 15 of Set 7 | san policarpo
# Processing Record 16 of Set 7 | steamboat springs
# Processing Record 17 of Set 7 | taman
# Processing Record 18 of Set 7 | miraflores
# Processing Record 19 of Set 7 | shache
# Processing Record 20 of Set 7 | saskylakh
# Processing Record 21 of Set 7 | piacabucu
# Processing Record 22 of Set 7 | dire
# Processing Record 23 of Set 7 | cotonou
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | nexo
# Processing Record 26 of Set 7 | rach gia
# Processing Record 27 of Set 7 | hervey bay
# Processing Record 28 of Set 7 | saldanha
# Processing Record 29 of Set 7 | hayden
# Processing Record 30 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 7 | ucluelet
# Processing Record 32 of Set 7 | waingapu
# Processing Record 33 of Set 7 | tacoronte
# Processing Record 34 of Set 7 | saint george
# Processing Record 35 of Set 7 | xifeng
# Processing Record 36 of Set 7 | praia da vitoria
# Processing Record 37 of Set 7 | stephenville crossing
# Processing Record 38 of Set 7 | mnogovershinnyy
# Processing Record 39 of Set 7 | shimoda
# Processing Record 40 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 7 | mattru
# Processing Record 42 of Set 7 | lazo
# Processing Record 43 of Set 7 | eidfjord
# Processing Record 44 of Set 7 | gunjur
# Processing Record 45 of Set 7 | kingisepp
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | arkhipo-osipovka
# Processing Record 48 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 7 | le gosier
# Processing Record 50 of Set 7 | brewster
# Processing Record 1 of Set 8 | goundam
# Processing Record 2 of Set 8 | hamilton
# Processing Record 3 of Set 8 | brzeziny
# Processing Record 4 of Set 8 | pochutla
# Processing Record 5 of Set 8 | vila
# Processing Record 6 of Set 8 | leshukonskoye
# Processing Record 7 of Set 8 | pangnirtung
# Processing Record 8 of Set 8 | northam
# Processing Record 9 of Set 8 | geraldton
# Processing Record 10 of Set 8 | tuy hoa
# Processing Record 11 of Set 8 | matamoros
# Processing Record 12 of Set 8 | chimore
# Processing Record 13 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 14 of Set 8 | havelock
# Processing Record 15 of Set 8 | bonavista
# Processing Record 16 of Set 8 | sept-iles
# Processing Record 17 of Set 8 | ust-barguzin
# Processing Record 18 of Set 8 | novyy urengoy
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | lagoa
# Processing Record 21 of Set 8 | verkh-usugli
# Processing Record 22 of Set 8 | derzhavinsk
# Processing Record 23 of Set 8 | amapa
# Processing Record 24 of Set 8 | komsomolskiy
# Processing Record 25 of Set 8 | golden
# Processing Record 26 of Set 8 | sikasso
# Processing Record 27 of Set 8 | alice springs
# Processing Record 28 of Set 8 | colares
# Processing Record 29 of Set 8 | hirara
# Processing Record 30 of Set 8 | krasnogorsk
# Processing Record 31 of Set 8 | moissala
# Processing Record 32 of Set 8 | erzin
# Processing Record 33 of Set 8 | gorin
# Processing Record 34 of Set 8 | kurmanayevka
# Processing Record 35 of Set 8 | limoges
# Processing Record 36 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 8 | sorland
# Processing Record 39 of Set 8 | manicore
# Processing Record 40 of Set 8 | muswellbrook
# Processing Record 41 of Set 8 | inzer
# Processing Record 42 of Set 8 | seoul
# Processing Record 43 of Set 8 | beohari
# Processing Record 44 of Set 8 | umtata
# Processing Record 45 of Set 8 | tasbuget
# City not found. Skipping...
# Processing Record 46 of Set 8 | ostrovnoy
# Processing Record 47 of Set 8 | camaguey
# Processing Record 48 of Set 8 | san
# Processing Record 49 of Set 8 | tangi
# Processing Record 50 of Set 8 | saurimo
# Processing Record 1 of Set 9 | tura
# Processing Record 2 of Set 9 | gardiner
# Processing Record 3 of Set 9 | flin flon
# Processing Record 4 of Set 9 | half moon bay
# Processing Record 5 of Set 9 | talara
# Processing Record 6 of Set 9 | marsh harbour
# Processing Record 7 of Set 9 | zholymbet
# Processing Record 8 of Set 9 | paamiut
# Processing Record 9 of Set 9 | basoko
# Processing Record 10 of Set 9 | sarmizegetusa
# Processing Record 11 of Set 9 | tadine
# Processing Record 12 of Set 9 | lavrentiya
# Processing Record 13 of Set 9 | bambous virieux
# Processing Record 14 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 9 | constantine
# Processing Record 17 of Set 9 | weyburn
# Processing Record 18 of Set 9 | adrar
# Processing Record 19 of Set 9 | longyearbyen
# Processing Record 20 of Set 9 | sobolevo
# Processing Record 21 of Set 9 | imeni poliny osipenko
# Processing Record 22 of Set 9 | vao
# Processing Record 23 of Set 9 | brigham city
# Processing Record 24 of Set 9 | rawson
# Processing Record 25 of Set 9 | emirdag
# Processing Record 26 of Set 9 | cap-aux-meules
# Processing Record 27 of Set 9 | lengshuitan
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | baft
# Processing Record 30 of Set 9 | san quintin
# Processing Record 31 of Set 9 | talnakh
# Processing Record 32 of Set 9 | illapel
# Processing Record 33 of Set 9 | turukhansk
# Processing Record 34 of Set 9 | waipawa
# Processing Record 35 of Set 9 | kostomuksha
# Processing Record 36 of Set 9 | westport
# Processing Record 37 of Set 9 | emba
# Processing Record 38 of Set 9 | mamallapuram
# Processing Record 39 of Set 9 | buraydah
# Processing Record 40 of Set 9 | palora
# Processing Record 41 of Set 9 | lysyye gory
# Processing Record 42 of Set 9 | kibuye
# Processing Record 43 of Set 9 | fallbrook
# Processing Record 44 of Set 9 | bardiyah
# Processing Record 45 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 9 | reconquista
# Processing Record 47 of Set 9 | padang
# Processing Record 48 of Set 9 | tshela
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | osa
# Processing Record 1 of Set 10 | yenagoa
# Processing Record 2 of Set 10 | rudnyy
# Processing Record 3 of Set 10 | pisco
# Processing Record 4 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 5 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 6 of Set 10 | hualmay
# Processing Record 7 of Set 10 | fortuna
# Processing Record 8 of Set 10 | axim
# Processing Record 9 of Set 10 | follebu
# Processing Record 10 of Set 10 | charters towers
# Processing Record 11 of Set 10 | norrtalje
# Processing Record 12 of Set 10 | tevaitoa
# Processing Record 13 of Set 10 | shcholkine
# City not found. Skipping...
# Processing Record 14 of Set 10 | garowe
# Processing Record 15 of Set 10 | nioro
# Processing Record 16 of Set 10 | maniitsoq
# Processing Record 17 of Set 10 | mpongwe
# Processing Record 18 of Set 10 | makow mazowiecki
# Processing Record 19 of Set 10 | lahat
# Processing Record 20 of Set 10 | vardo
# Processing Record 21 of Set 10 | flinders
# Processing Record 22 of Set 10 | kagalnitskaya
# Processing Record 23 of Set 10 | pafos
# Processing Record 24 of Set 10 | misratah
# Processing Record 25 of Set 10 | port augusta
# Processing Record 26 of Set 10 | tacna
# Processing Record 27 of Set 10 | pangody
# Processing Record 28 of Set 10 | ilhabela
# Processing Record 29 of Set 10 | svetlogorsk
# Processing Record 30 of Set 10 | mutoko
# Processing Record 31 of Set 10 | port hedland
# Processing Record 32 of Set 10 | puerto del rosario
# Processing Record 33 of Set 10 | san angelo
# Processing Record 34 of Set 10 | niigata
# Processing Record 35 of Set 10 | sandusky
# Processing Record 36 of Set 10 | corpus christi
# Processing Record 37 of Set 10 | orlik
# Processing Record 38 of Set 10 | raniganj
# Processing Record 39 of Set 10 | anshun
# Processing Record 40 of Set 10 | shubarkuduk
# Processing Record 41 of Set 10 | zhigalovo
# Processing Record 42 of Set 10 | sahuaripa
# Processing Record 43 of Set 10 | quang ngai
# Processing Record 44 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 10 | tagusao
# Processing Record 46 of Set 10 | namie
# Processing Record 47 of Set 10 | uyutne
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | kyabram
# Processing Record 50 of Set 10 | stornoway
# Processing Record 1 of Set 11 | luganville
# Processing Record 2 of Set 11 | yatou
# Processing Record 3 of Set 11 | potsdam
# Processing Record 4 of Set 11 | tomatlan
# Processing Record 5 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 11 | bridgewater
# Processing Record 7 of Set 11 | yulara
# Processing Record 8 of Set 11 | beipiao
# Processing Record 9 of Set 11 | yinchuan
# Processing Record 10 of Set 11 | kambove
# Processing Record 11 of Set 11 | manzanillo
# Processing Record 12 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 11 | pingshan
# Processing Record 14 of Set 11 | gamba
# Processing Record 15 of Set 11 | ixtapa
# Processing Record 16 of Set 11 | pingliang
# Processing Record 17 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 11 | minnedosa
# Processing Record 19 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | thohoyandou
# Processing Record 21 of Set 11 | lardos
# Processing Record 22 of Set 11 | kaoma
# Processing Record 23 of Set 11 | shieli
# Processing Record 24 of Set 11 | carballo
# Processing Record 25 of Set 11 | excelsior springs
# Processing Record 26 of Set 11 | pasni
# Processing Record 27 of Set 11 | amnat charoen
# Processing Record 28 of Set 11 | jeremoabo
# Processing Record 29 of Set 11 | ipixuna
# Processing Record 30 of Set 11 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 31 of Set 11 | ornskoldsvik
# Processing Record 32 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 11 | griffith
# Processing Record 35 of Set 11 | maragogi
# Processing Record 36 of Set 11 | marawi
# Processing Record 37 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 11 | quatre cocos
# Processing Record 39 of Set 11 | araguacu
# Processing Record 40 of Set 11 | simoes
# Processing Record 41 of Set 11 | semporna
# Processing Record 42 of Set 11 | verkhoyansk
# Processing Record 43 of Set 11 | dali
# Processing Record 44 of Set 11 | kenora
# Processing Record 45 of Set 11 | vikhorevka
# Processing Record 46 of Set 11 | qui nhon
# Processing Record 47 of Set 11 | nizwa
# Processing Record 48 of Set 11 | mogadishu
# Processing Record 49 of Set 11 | tinde
# Processing Record 50 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 1 of Set 12 | calama
# Processing Record 2 of Set 12 | bay roberts
# Processing Record 3 of Set 12 | sovetskiy
# Processing Record 4 of Set 12 | dhidhdhoo
# Processing Record 5 of Set 12 | denpasar
# Processing Record 6 of Set 12 | kristallopiyi
# City not found. Skipping...
# Processing Record 7 of Set 12 | vanavara
# Processing Record 8 of Set 12 | umm lajj
# Processing Record 9 of Set 12 | san felipe
# Processing Record 10 of Set 12 | the pas
# Processing Record 11 of Set 12 | mabaruma
# Processing Record 12 of Set 12 | ankazoabo
# Processing Record 13 of Set 12 | surt
# Processing Record 14 of Set 12 | kota kinabalu
# Processing Record 15 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 12 | guozhen
# Processing Record 17 of Set 12 | tretten
# Processing Record 18 of Set 12 | nador
# Processing Record 19 of Set 12 | mao
# Processing Record 20 of Set 12 | belmonte
# Processing Record 21 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 23 of Set 12 | wad rawah
# Processing Record 24 of Set 12 | occhiobello
# Processing Record 25 of Set 12 | cururupu
# Processing Record 26 of Set 12 | yantal
# Processing Record 27 of Set 12 | biak
# Processing Record 28 of Set 12 | kautokeino
# Processing Record 29 of Set 12 | hailar
# Processing Record 30 of Set 12 | suhut
# Processing Record 31 of Set 12 | strezhevoy
# Processing Record 32 of Set 12 | kawalu
# Processing Record 33 of Set 12 | dakar
# Processing Record 34 of Set 12 | saint-augustin
# Processing Record 35 of Set 12 | szydlowiec
# Processing Record 36 of Set 12 | healdsburg
# Processing Record 37 of Set 12 | bandarbeyla
# Processing Record 38 of Set 12 | el dorado
# Processing Record 39 of Set 12 | ongandjera
# Processing Record 40 of Set 12 | bahia de caraquez
# Processing Record 41 of Set 12 | portland
# Processing Record 42 of Set 12 | ketchikan
# Processing Record 43 of Set 12 | nemuro
# Processing Record 44 of Set 12 | pocone
# Processing Record 45 of Set 12 | anadyr
# Processing Record 46 of Set 12 | tambun
# Processing Record 47 of Set 12 | tilichiki
# Processing Record 48 of Set 12 | nuuk
# Processing Record 49 of Set 12 | thunder bay
# Processing Record 50 of Set 12 | karaul
# City not found. Skipping...

# %%
# Convert the array of dictionaries to a Pandas Dataframe.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["column1", "column8", "column9", "column2", "column3", "column4", "column5", "column6", "column7"]
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot. 
plt.show()

# %%
# Build the scatter plots for latitude vs humidity.
plt.scatter(lats,
           humidity,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs cloudiness.
plt.scatter(lats,
           cloudiness,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs wind speed.
plt.scatter(lats,
           wind_speed,
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress 
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_error) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y =" + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemishphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Maximum Temperature', 'Max Temp', (10,40))

# %%
# Linear regression on the Northern Hemishphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Maximum Temperature', 'Max Temp', (-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere for % Cloudiness', '% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(35,30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-30,15))
